# %%
#%python
#import requests

# %%
#url = 'https://collectionapi.metmuseum.org/public/collection/v1/search?q=sunflowers' 

#response = requests.get(url)

#response

"""
Connection failed, could not connect to Met API with the free version of Databricks serverless compute

Connection failed: HTTPSConnectionPool(host='collectionapi.metmuseum.org', port=443): Max retries exceeded with url: /public/collection/v1/search?q=sunflowers (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0xffa0730517f0>: Failed to resolve 'collectionapi.metmuseum.org' ([Errno -3] Temporary failure in name resolution)"))

Serverless compute cannot reach external APIs.
Options:
1. Switch to a standard cluster with internet access
2. Use a proxy or gateway configured for your workspace
3. Download the data externally and upload to a volume/table

Will continue in VS code within the repo instead of using Databricks for this step
"""
